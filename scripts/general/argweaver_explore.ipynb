# %%
import polars as pl
import plotly.express as px

# %%
df = pl.read_csv("/home/joseph/hoiho/ARG/arg-sample.stats", separator="\t")
df.head()

# %%
# Only stage == resample
df = df.filter(pl.col("stage") == "resample")

# %%
px.line(df.to_pandas(), x="iter", y=["likelihood"])

# %%
px.line(df.to_pandas(), x="iter", y=["prior", "prior2"])

# %%
px.line(df.to_pandas(), x="iter", y="recombs")

# %%
px.line(df.to_pandas(), x="iter", y="prior")
